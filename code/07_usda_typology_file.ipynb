# %%
"""
Import USDA file with county typology data

Output to pickle
"""
# Out:
# '\nFilter data file with population data from USDA to year 2019.\nPivot table from tall to wide.\n\nOutput to pickle\n'

# %%
import pandas as pd
import numpy as np
import pickle

# %%
cnty_typol = pd.read_csv('../data/2015CountyTypologyCodes.csv', encoding='unicode-escape')
cnty_typol.shape
# Out:
# (3143, 18)

# %%
cnty_typol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3143 entries, 0 to 3142
# Data columns (total 18 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   FIPStxt                                          3143 non-null   int64
#  1   State                                            3143 non-null   object
#  2   County_name                                      3143 non-null   object
#  3   Metro-nonmetro status, 2013 0=Nonmetro 1=Metro   3143 non-null   int64
#  4   Economic Types Type_2015_Update non-overlapping  3143 non-null   int64
#  5   Economic_Type_Label                              3143 non-null   object
#  6   Farming_2015_Update                              3143 non-null   int64
#  7   Mining_2015-Update                               3143 non-null   int64
#  8   Manufacturing_2015_Update                        3143 non-null   int64
# ...

# %%
cnty_typol.head(10)
# Out:
#    FIPStxt State      County_name  \
# 0     1001    AL   Autauga County
# 1     1003    AL   Baldwin County
# 2     1005    AL   Barbour County
# 3     1007    AL      Bibb County
# 4     1009    AL    Blount County
# 5     1011    AL   Bullock County
# 6     1013    AL    Butler County
# 7     1015    AL   Calhoun County
# 8     1017    AL  Chambers County
# 9     1019    AL  Cherokee County
#
#    Metro-nonmetro status, 2013 0=Nonmetro 1=Metro  \
# 0                                               1
# 1                                               1
# 2                                               0
# 3                                               1
# 4                                               1
# 5                                               0
# 6                                               0
# 7                                               1
# 8                                               0
# 9                                               0
#
# ...

# %%
cnty_typol.columns
# Out:
# Index(['FIPStxt', 'State', 'County_name',
#        'Metro-nonmetro status, 2013 0=Nonmetro 1=Metro',
#        'Economic Types Type_2015_Update non-overlapping',
#        'Economic_Type_Label', 'Farming_2015_Update', 'Mining_2015-Update',
#        'Manufacturing_2015_Update', 'Government_2015_Update',
#        'Recreation_2015_Update', 'Nonspecialized_2015_Update',
#        'Low_Education_2015_Update', 'Low_Employment_Cnty_2008_2012_25_64',
#        'Pop_Loss_2010', 'Retirement_Dest_2015_Update',
#        'Persistent_Poverty_2013', 'Persistent_Related_Child_Poverty_2013'],
#       dtype='object')

# %%
with open('county_typology.pickle', 'wb') as to_write:
    pickle.dump(cnty_typol, to_write)
