# %%
"""
combine data gathered and saved in several pickle files

output to one combined pickle file
"""

# %%
import pickle
import pandas as pd
import numpy as np

# %%
# state FIPS codes
with open('st_fips_codes.pickle', 'rb') as read_file:
    fips_codes = pickle.load(read_file)
    
fips_codes.head()
# Out:
#         state abbr FIPS
# 0     Alabama   AL   01
# 1      Alaska   AK   02
# 2     Arizona   AZ   04
# 3    Arkansas   AR   05
# 4  California   CA   06

# %%
# features from Wikipedia
with open('county_features.pickle', 'rb') as read_file:
    county_features = pickle.load(read_file)
    
county_features.head()
# Out:
#      state              county_name FIPS_code  \
# 0  Alabama  Autauga County, Alabama       001
# 1  Alabama  Baldwin County, Alabama       003
# 2  Alabama  Barbour County, Alabama       005
# 3  Alabama     Bibb County, Alabama       007
# 4  Alabama   Blount County, Alabama       009
#
#                                      county_page_url  \
# 0  https://en.wikipedia.org/wiki/Autauga_County,_...
# 1  https://en.wikipedia.org/wiki/Baldwin_County,_...
# 2  https://en.wikipedia.org/wiki/Barbour_County,_...
# 3  https://en.wikipedia.org/wiki/Bibb_County,_Ala...
# 4  https://en.wikipedia.org/wiki/Blount_County,_A...
#
#                                             highways  hwy_count  \
# 0  [Interstate 65, U.S. Highway 31, U.S. Highway ...          6
# 1  [Interstate 10, Interstate 65, U.S. Highway 31...         12
# 2  [U.S. Highway 82, U.S. Highway 431, State Rout...         11
# 3  [U.S. Highway 11, U.S. Highway 82, State Route...          8
# 4  [Interstate 65, U.S. Highway 31, U.S. Highway ...          9
#
#                                               cities  city_count  \
# 0                            [Millbrook, Prattville]           2
# 1  [Bay Minette, Daphne, Fairhope, Foley, Gulf Sh...           8
# 2                                    [Clio, Eufaula]           2
# 3                               [Brent, Centreville]           2
# 4                                 [Oneonta, Warrior]           2
#
#                                                towns  town_count
# 0                        [Autaugaville, Billingsley]           2
# 1  [Elberta, Loxley, Magnolia Springs, Perdido Be...           6
# 2     [Bakerhill, Blue Springs, Clayton, Louisville]           4
# 3                   [Vance, West Blocton, Woodstock]           3
# 4  [Allgood, Altoona, Blountsville, Cleveland, Co...          14

# %%
county_features.dtypes
# Out:
# state              object
# county_name        object
# FIPS_code          object
# county_page_url    object
# highways           object
# hwy_count           int64
# cities             object
# city_count          int64
# towns              object
# town_count          int64
# dtype: object

# %%
# add state fips code to county features df
# check state names exactly the same

# %%
county_features['state'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Florida',
#        'Georgia (U.S. state)', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York (state)', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington (state)',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
fips_codes['state'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont',
#        'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming',
#        'American Samoa', 'Guam', 'Northern Mariana Islands',
#        'Puerto Rico', 'Virgin Islands'], dtype=object)

# %%
# revise state names in the county features df to remove specification of (state)
county_features.loc[county_features['state'] == 'Georgia (U.S. state)', ['state']] = 'Georgia'
county_features.loc[county_features['state'] == 'New York (state)', ['state']] = 'New York'
county_features.loc[county_features['state'] == 'Washington (state)', ['state']] = 'Washington'

# %%
county_features['state'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont',
#        'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype=object)

# %%
cnty_features = pd.merge(county_features, fips_codes, how='left', on='state' )
cnty_features.head()
# Out:
#      state              county_name FIPS_code  \
# 0  Alabama  Autauga County, Alabama       001
# 1  Alabama  Baldwin County, Alabama       003
# 2  Alabama  Barbour County, Alabama       005
# 3  Alabama     Bibb County, Alabama       007
# 4  Alabama   Blount County, Alabama       009
#
#                                      county_page_url  \
# 0  https://en.wikipedia.org/wiki/Autauga_County,_...
# 1  https://en.wikipedia.org/wiki/Baldwin_County,_...
# 2  https://en.wikipedia.org/wiki/Barbour_County,_...
# 3  https://en.wikipedia.org/wiki/Bibb_County,_Ala...
# 4  https://en.wikipedia.org/wiki/Blount_County,_A...
#
#                                             highways  hwy_count  \
# 0  [Interstate 65, U.S. Highway 31, U.S. Highway ...          6
# 1  [Interstate 10, Interstate 65, U.S. Highway 31...         12
# 2  [U.S. Highway 82, U.S. Highway 431, State Rout...         11
# 3  [U.S. Highway 11, U.S. Highway 82, State Route...          8
# 4  [Interstate 65, U.S. Highway 31, U.S. Highway ...          9
#
#                                               cities  city_count  \
# 0                            [Millbrook, Prattville]           2
# 1  [Bay Minette, Daphne, Fairhope, Foley, Gulf Sh...           8
# 2                                    [Clio, Eufaula]           2
# 3                               [Brent, Centreville]           2
# 4                                 [Oneonta, Warrior]           2
#
#                                                towns  town_count abbr FIPS
# 0                        [Autaugaville, Billingsley]           2   AL   01
# 1  [Elberta, Loxley, Magnolia Springs, Perdido Be...           6   AL   01
# 2     [Bakerhill, Blue Springs, Clayton, Louisville]           4   AL   01
# 3                   [Vance, West Blocton, Woodstock]           3   AL   01
# 4  [Allgood, Altoona, Blountsville, Cleveland, Co...          14   AL   01

# %%
cnty_features.tail()
# Out:
#         state                 county_name FIPS_code  \
# 3089  Wyoming  Sweetwater County, Wyoming       037
# 3090  Wyoming       Teton County, Wyoming       039
# 3091  Wyoming       Uinta County, Wyoming       041
# 3092  Wyoming    Washakie County, Wyoming       043
# 3093  Wyoming      Weston County, Wyoming       045
#
#                                         county_page_url  \
# 3089  https://en.wikipedia.org/wiki/Sweetwater_Count...
# 3090  https://en.wikipedia.org/wiki/Teton_County,_Wy...
# 3091  https://en.wikipedia.org/wiki/Uinta_County,_Wy...
# 3092  https://en.wikipedia.org/wiki/Washakie_County,...
# 3093  https://en.wikipedia.org/wiki/Weston_County,_W...
#
#                                                highways  hwy_count  \
# 3089                                                 []          0
# 3090                                                 []          0
# 3091                  [Interstate 80, U.S. Highway 189]          2
# 3092                                                 []          0
# 3093  [U.S. Highway 16, U.S. Highway 20, U.S. Highwa...          6
#
#                            cities  city_count  \
# 3089  [Green River, Rock Springs]           2
# 3090                           []           2
# 3091                   [Evanston]           1
# 3092                    [Worland]           1
# 3093                  [Newcastle]           1
#
#                                         towns  town_count abbr FIPS
# 3089  [Bairoil, Granger, Superior, Wamsutter]           4   WY   56
# 3090                                [Jackson]           1   WY   56
# 3091       [Bear River, Lyman, Mountain View]           3   WY   56
# 3092                              [Ten Sleep]           1   WY   56
# 3093                                  [Upton]           1   WY   56

# %%
# import pickle files with usda data

with open('pop_est_2019.pickle', 'rb') as read_file:
    pop_est = pickle.load(read_file)
    
    
pop_est.head()
# Out:
#    FIPStxt State       Area_Name POP_ESTIMATE_2019 N_POP_CHG_2019
# 0        0    US   United States       328,239,523      1,552,022
# 1     1000    AL         Alabama         4,903,185         15,504
# 2     1001    AL  Autauga County            55,869            336
# 3     1003    AL  Baldwin County           223,234          5,379
# 4     1005    AL  Barbour County            24,686           -186

# %%
pop_est.dtypes
# Out:
# FIPStxt               int64
# State                object
# Area_Name            object
# POP_ESTIMATE_2019    object
# N_POP_CHG_2019       object
# dtype: object

# %%
pop_est['FIPStxt'] = pop_est['FIPStxt'].astype(str)
pop_est.dtypes
# Out:
# FIPStxt              object
# State                object
# Area_Name            object
# POP_ESTIMATE_2019    object
# N_POP_CHG_2019       object
# dtype: object

# %%
# keep only counties in pop_est df

cnty_pop_est = pop_est[pop_est['FIPStxt'].str[-1] != '0']

cnty_pop_est.head()
# Out:
#   FIPStxt State       Area_Name POP_ESTIMATE_2019 N_POP_CHG_2019
# 2    1001    AL  Autauga County            55,869            336
# 3    1003    AL  Baldwin County           223,234          5,379
# 4    1005    AL  Barbour County            24,686           -186
# 5    1007    AL     Bibb County            22,394             27
# 6    1009    AL   Blount County            57,826             55

# %%
cnty_pop_est['FIPS_code'] = cnty_pop_est['FIPStxt'].apply(lambda x: str(x).zfill(5))
# Out:
# <ipython-input-15-88370c02bcb5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cnty_pop_est['FIPS_code'] = cnty_pop_est['FIPStxt'].apply(lambda x: str(x).zfill(5))

# %%
cnty_pop_est.head()
# Out:
#   FIPStxt State       Area_Name POP_ESTIMATE_2019 N_POP_CHG_2019 FIPS_code
# 2    1001    AL  Autauga County            55,869            336     01001
# 3    1003    AL  Baldwin County           223,234          5,379     01003
# 4    1005    AL  Barbour County            24,686           -186     01005
# 5    1007    AL     Bibb County            22,394             27     01007
# 6    1009    AL   Blount County            57,826             55     01009

# %%
len(cnty_pop_est)
# Out:
# 3170

# %%
with open('unemp_inc_pivot.pickle', 'rb') as read_file:
    unemp_inc = pickle.load(read_file)
    
unemp_inc.head()
# Out:
# Attribute  fips_txt Stabr           area_name  Civilian_labor_force_2019  \
# 0                 0    US       United States                163100055.0
# 1              1000    AL             Alabama                  2241747.0
# 2              1001    AL  Autauga County, AL                    26172.0
# 3              1003    AL  Baldwin County, AL                    97328.0
# 4              1005    AL  Barbour County, AL                     8537.0
#
# Attribute  Employed_2019  Med_HH_Income_Percent_of_State_Total_2019  \
# 0            157115247.0                                        NaN
# 1              2174483.0                                 100.000000
# 2                25458.0                                 112.481888
# 3                94675.0                                 115.645828
# 4                 8213.0                                  69.482918
#
# Attribute  Median_Household_Income_2019  Metro_2013  \
# 0                               65712.0         NaN
# 1                               51771.0         NaN
# 2                               58233.0         1.0
# 3                               59871.0         1.0
# 4                               35972.0         0.0
#
# Attribute  Rural_urban_continuum_code_2013  Unemployed_2019  \
# 0                                      NaN        5984808.0
# 1                                      NaN          67264.0
# 2                                      2.0            714.0
# 3                                      3.0           2653.0
# 4                                      6.0            324.0
#
# Attribute  Unemployment_rate_2019  Urban_influence_code_2013
# 0                        3.669409                        NaN
# 1                        3.000000                        NaN
# 2                        2.700000                        2.0
# 3                        2.700000                        2.0
# 4                        3.800000                        6.0

# %%
unemp_inc.dtypes
# Out:
# Attribute
# fips_txt                                       int64
# Stabr                                         object
# area_name                                     object
# Civilian_labor_force_2019                    float64
# Employed_2019                                float64
# Med_HH_Income_Percent_of_State_Total_2019    float64
# Median_Household_Income_2019                 float64
# Metro_2013                                   float64
# Rural_urban_continuum_code_2013              float64
# Unemployed_2019                              float64
# Unemployment_rate_2019                       float64
# Urban_influence_code_2013                    float64
# dtype: object

# %%
unemp_inc['fips_txt'] = unemp_inc['fips_txt'].astype(str)
unemp_inc.dtypes
# Out:
# Attribute
# fips_txt                                      object
# Stabr                                         object
# area_name                                     object
# Civilian_labor_force_2019                    float64
# Employed_2019                                float64
# Med_HH_Income_Percent_of_State_Total_2019    float64
# Median_Household_Income_2019                 float64
# Metro_2013                                   float64
# Rural_urban_continuum_code_2013              float64
# Unemployed_2019                              float64
# Unemployment_rate_2019                       float64
# Urban_influence_code_2013                    float64
# dtype: object

# %%
# keep only counties
cnty_unemp_inc = unemp_inc[unemp_inc['fips_txt'].str[-1] != '0']
cnty_unemp_inc.head()
# Out:
# Attribute fips_txt Stabr           area_name  Civilian_labor_force_2019  \
# 2             1001    AL  Autauga County, AL                    26172.0
# 3             1003    AL  Baldwin County, AL                    97328.0
# 4             1005    AL  Barbour County, AL                     8537.0
# 5             1007    AL     Bibb County, AL                     8685.0
# 6             1009    AL   Blount County, AL                    25331.0
#
# Attribute  Employed_2019  Med_HH_Income_Percent_of_State_Total_2019  \
# 2                25458.0                                 112.481888
# 3                94675.0                                 115.645828
# 4                 8213.0                                  69.482918
# 5                 8419.0                                  92.557610
# 6                24655.0                                 102.184624
#
# Attribute  Median_Household_Income_2019  Metro_2013  \
# 2                               58233.0         1.0
# 3                               59871.0         1.0
# 4                               35972.0         0.0
# 5                               47918.0         1.0
# 6                               52902.0         1.0
#
# Attribute  Rural_urban_continuum_code_2013  Unemployed_2019  \
# 2                                      2.0            714.0
# 3                                      3.0           2653.0
# 4                                      6.0            324.0
# 5                                      1.0            266.0
# 6                                      1.0            676.0
#
# Attribute  Unemployment_rate_2019  Urban_influence_code_2013
# 2                             2.7                        2.0
# 3                             2.7                        2.0
# 4                             3.8                        6.0
# 5                             3.1                        1.0
# 6                             2.7                        1.0

# %%
len(cnty_unemp_inc)
# Out:
# 3171

# %%
# fips_txt needs leading 0 for states 1-9

cnty_unemp_inc['FIPS_code'] = cnty_unemp_inc['fips_txt'].apply(lambda x: str(x).zfill(5))

cnty_unemp_inc.head()
# Out:
# <ipython-input-24-db47ee5de3af>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cnty_unemp_inc['FIPS_code'] = cnty_unemp_inc['fips_txt'].apply(lambda x: str(x).zfill(5))
# Attribute fips_txt Stabr           area_name  Civilian_labor_force_2019  \
# 2             1001    AL  Autauga County, AL                    26172.0
# 3             1003    AL  Baldwin County, AL                    97328.0
# 4             1005    AL  Barbour County, AL                     8537.0
# 5             1007    AL     Bibb County, AL                     8685.0
# 6             1009    AL   Blount County, AL                    25331.0
#
# Attribute  Employed_2019  Med_HH_Income_Percent_of_State_Total_2019  \
# 2                25458.0                                 112.481888
# 3                94675.0                                 115.645828
# 4                 8213.0                                  69.482918
# 5                 8419.0                                  92.557610
# 6                24655.0                                 102.184624
#
# Attribute  Median_Household_Income_2019  Metro_2013  \
# 2                               58233.0         1.0
# 3                               59871.0         1.0
# 4                               35972.0         0.0
# 5                               47918.0         1.0
# 6                               52902.0         1.0
#
# Attribute  Rural_urban_continuum_code_2013  Unemployed_2019  \
# 2                                      2.0            714.0
# 3                                      3.0           2653.0
# 4                                      6.0            324.0
# 5                                      1.0            266.0
# 6                                      1.0            676.0
#
# Attribute  Unemployment_rate_2019  Urban_influence_code_2013 FIPS_code
# 2                             2.7                        2.0     01001
# 3                             2.7                        2.0     01003
# 4                             3.8                        6.0     01005
# 5                             3.1                        1.0     01007
# 6                             2.7                        1.0     01009

# %%
# new column to combine state FIPS and county FIPS in cnty_features df

cnty_features['FIPS_code_NEW'] = cnty_features['FIPS'] + cnty_features['FIPS_code']
cnty_features.head()
# Out:
#      state              county_name FIPS_code  \
# 0  Alabama  Autauga County, Alabama       001
# 1  Alabama  Baldwin County, Alabama       003
# 2  Alabama  Barbour County, Alabama       005
# 3  Alabama     Bibb County, Alabama       007
# 4  Alabama   Blount County, Alabama       009
#
#                                      county_page_url  \
# 0  https://en.wikipedia.org/wiki/Autauga_County,_...
# 1  https://en.wikipedia.org/wiki/Baldwin_County,_...
# 2  https://en.wikipedia.org/wiki/Barbour_County,_...
# 3  https://en.wikipedia.org/wiki/Bibb_County,_Ala...
# 4  https://en.wikipedia.org/wiki/Blount_County,_A...
#
#                                             highways  hwy_count  \
# 0  [Interstate 65, U.S. Highway 31, U.S. Highway ...          6
# 1  [Interstate 10, Interstate 65, U.S. Highway 31...         12
# 2  [U.S. Highway 82, U.S. Highway 431, State Rout...         11
# 3  [U.S. Highway 11, U.S. Highway 82, State Route...          8
# 4  [Interstate 65, U.S. Highway 31, U.S. Highway ...          9
#
#                                               cities  city_count  \
# 0                            [Millbrook, Prattville]           2
# 1  [Bay Minette, Daphne, Fairhope, Foley, Gulf Sh...           8
# 2                                    [Clio, Eufaula]           2
# 3                               [Brent, Centreville]           2
# 4                                 [Oneonta, Warrior]           2
#
#                                                towns  town_count abbr FIPS  \
# 0                        [Autaugaville, Billingsley]           2   AL   01
# 1  [Elberta, Loxley, Magnolia Springs, Perdido Be...           6   AL   01
# 2     [Bakerhill, Blue Springs, Clayton, Louisville]           4   AL   01
# 3                   [Vance, West Blocton, Woodstock]           3   AL   01
# 4  [Allgood, Altoona, Blountsville, Cleveland, Co...          14   AL   01
#
#   FIPS_code_NEW
# 0         01001
# 1         01003
# 2         01005
# 3         01007
# 4         01009

# %%
with open('county_typology.pickle', 'rb') as read_file:
    cnty_type = pickle.load(read_file)
    
cnty_type.head()
# Out:
#    FIPStxt State     County_name  \
# 0     1001    AL  Autauga County
# 1     1003    AL  Baldwin County
# 2     1005    AL  Barbour County
# 3     1007    AL     Bibb County
# 4     1009    AL   Blount County
#
#    Metro-nonmetro status, 2013 0=Nonmetro 1=Metro  \
# 0                                               1
# 1                                               1
# 2                                               0
# 3                                               1
# 4                                               1
#
#    Economic Types Type_2015_Update non-overlapping Economic_Type_Label  \
# 0                                                0      Nonspecialized
# 1                                                5          Recreation
# 2                                                3        Maufacturing
# 3                                                0      Nonspecialized
# 4                                                0      Nonspecialized
#
#    Farming_2015_Update  Mining_2015-Update  Manufacturing_2015_Update  \
# 0                    0                   0                          0
# 1                    0                   0                          0
# 2                    0                   0                          1
# 3                    0                   0                          0
# 4                    0                   0                          0
#
#    Government_2015_Update  Recreation_2015_Update  Nonspecialized_2015_Update  \
# 0                       0                       0                           1
# 1                       0                       1                           0
# 2                       0                       0                           0
# 3                       0                       0                           1
# 4                       0                       0                           1
#
#    Low_Education_2015_Update  Low_Employment_Cnty_2008_2012_25_64  \
# 0                          0                                    0
# 1                          0                                    0
# 2                          1                                    1
# 3                          1                                    1
# 4                          1                                    1
#
#    Pop_Loss_2010  Retirement_Dest_2015_Update  Persistent_Poverty_2013  \
# 0              0                            1                        0
# 1              0                            1                        0
# 2              0                            0                        1
# 3              0                            0                        0
# 4              0                            0                        0
#
#    Persistent_Related_Child_Poverty_2013
# 0                                      0
# 1                                      0
# 2                                      1
# 3                                      1
# 4                                      0

# %%
len(cnty_type)
# Out:
# 3143

# %%
cnty_type['FIPS_code'] = cnty_type['FIPStxt'].apply(lambda x: str(x).zfill(5))

# %%
cnty_type.head()
# Out:
#    FIPStxt State     County_name  \
# 0     1001    AL  Autauga County
# 1     1003    AL  Baldwin County
# 2     1005    AL  Barbour County
# 3     1007    AL     Bibb County
# 4     1009    AL   Blount County
#
#    Metro-nonmetro status, 2013 0=Nonmetro 1=Metro  \
# 0                                               1
# 1                                               1
# 2                                               0
# 3                                               1
# 4                                               1
#
#    Economic Types Type_2015_Update non-overlapping Economic_Type_Label  \
# 0                                                0      Nonspecialized
# 1                                                5          Recreation
# 2                                                3        Maufacturing
# 3                                                0      Nonspecialized
# 4                                                0      Nonspecialized
#
#    Farming_2015_Update  Mining_2015-Update  Manufacturing_2015_Update  \
# 0                    0                   0                          0
# 1                    0                   0                          0
# 2                    0                   0                          1
# 3                    0                   0                          0
# 4                    0                   0                          0
#
#    Government_2015_Update  Recreation_2015_Update  Nonspecialized_2015_Update  \
# 0                       0                       0                           1
# 1                       0                       1                           0
# 2                       0                       0                           0
# 3                       0                       0                           1
# 4                       0                       0                           1
#
#    Low_Education_2015_Update  Low_Employment_Cnty_2008_2012_25_64  \
# 0                          0                                    0
# 1                          0                                    0
# 2                          1                                    1
# 3                          1                                    1
# 4                          1                                    1
#
#    Pop_Loss_2010  Retirement_Dest_2015_Update  Persistent_Poverty_2013  \
# 0              0                            1                        0
# 1              0                            1                        0
# 2              0                            0                        1
# 3              0                            0                        0
# 4              0                            0                        0
#
#    Persistent_Related_Child_Poverty_2013 FIPS_code
# 0                                      0     01001
# 1                                      0     01003
# 2                                      1     01005
# 3                                      1     01007
# 4                                      0     01009

# %%
# merge cnty_unemp_inc, cnty_pop_est, cnty_type, cnty_features


all_data_1 = pd.merge(cnty_unemp_inc, cnty_pop_est, how='left', on='FIPS_code')

# %%
all_data_2 = pd.merge(all_data_1, cnty_type, how='left', on='FIPS_code')

# %%
all_data_3 = pd.merge(all_data_2, cnty_features, how='left', left_on='FIPS_code', right_on='FIPS_code_NEW')

# %%
all_data_3
# Out:
#      fips_txt Stabr                area_name  Civilian_labor_force_2019  \
# 0        1001    AL       Autauga County, AL                    26172.0
# 1        1003    AL       Baldwin County, AL                    97328.0
# 2        1005    AL       Barbour County, AL                     8537.0
# 3        1007    AL          Bibb County, AL                     8685.0
# 4        1009    AL        Blount County, AL                    25331.0
# ...       ...   ...                      ...                        ...
# 3166    72145    PR  Vega Baja Municipio, PR                    13037.0
# 3167    72147    PR    Vieques Municipio, PR                     2585.0
# 3168    72149    PR   Villalba Municipio, PR                     7406.0
# 3169    72151    PR    Yabucoa Municipio, PR                     8691.0
# 3170    72153    PR      Yauco Municipio, PR                     9759.0
#
#       Employed_2019  Med_HH_Income_Percent_of_State_Total_2019  \
# 0           25458.0                                 112.481888
# 1           94675.0                                 115.645828
# 2            8213.0                                  69.482918
# 3            8419.0                                  92.557610
# 4           24655.0                                 102.184624
# ...             ...                                        ...
# 3166        11791.0                                        NaN
# 3167         2406.0                                        NaN
# 3168         6231.0                                        NaN
# 3169         7552.0                                        NaN
# 3170         8331.0                                        NaN
#
#       Median_Household_Income_2019  Metro_2013  \
# 0                          58233.0         1.0
# 1                          59871.0         1.0
# 2                          35972.0         0.0
# 3                          47918.0         1.0
# 4                          52902.0         1.0
# ...                            ...         ...
# 3166                           NaN         1.0
# 3167                           NaN         0.0
# 3168                           NaN         1.0
# 3169                           NaN         1.0
# 3170                           NaN         1.0
#
#       Rural_urban_continuum_code_2013  Unemployed_2019  ...  \
# 0                                 2.0            714.0  ...
# 1                                 3.0           2653.0  ...
# 2                                 6.0            324.0  ...
# 3                                 1.0            266.0  ...
# 4                                 1.0            676.0  ...
# ...                               ...              ...  ...
# 3166                              1.0           1246.0  ...
# 3167                              7.0            179.0  ...
# 3168                              2.0           1175.0  ...
# 3169                              1.0           1139.0  ...
# 3170                              2.0           1428.0  ...
#
#                                         county_page_url  \
# 0     https://en.wikipedia.org/wiki/Autauga_County,_...
# 1     https://en.wikipedia.org/wiki/Baldwin_County,_...
# 2     https://en.wikipedia.org/wiki/Barbour_County,_...
# 3     https://en.wikipedia.org/wiki/Bibb_County,_Ala...
# 4     https://en.wikipedia.org/wiki/Blount_County,_A...
# ...                                                 ...
# 3166                                                NaN
# 3167                                                NaN
# 3168                                                NaN
# 3169                                                NaN
# 3170                                                NaN
#
#                                                highways hwy_count  \
# 0     [Interstate 65, U.S. Highway 31, U.S. Highway ...       6.0
# 1     [Interstate 10, Interstate 65, U.S. Highway 31...      12.0
# 2     [U.S. Highway 82, U.S. Highway 431, State Rout...      11.0
# 3     [U.S. Highway 11, U.S. Highway 82, State Route...       8.0
# 4     [Interstate 65, U.S. Highway 31, U.S. Highway ...       9.0
# ...                                                 ...       ...
# 3166                                                NaN       NaN
# 3167                                                NaN       NaN
# 3168                                                NaN       NaN
# 3169                                                NaN       NaN
# 3170                                                NaN       NaN
#
#                                                  cities city_count  \
# 0                               [Millbrook, Prattville]        2.0
# 1     [Bay Minette, Daphne, Fairhope, Foley, Gulf Sh...        8.0
# 2                                       [Clio, Eufaula]        2.0
# 3                                  [Brent, Centreville]        2.0
# 4                                    [Oneonta, Warrior]        2.0
# ...                                                 ...        ...
# 3166                                                NaN        NaN
# 3167                                                NaN        NaN
# 3168                                                NaN        NaN
# 3169                                                NaN        NaN
# 3170                                                NaN        NaN
#
#                                                   towns town_count abbr  FIPS  \
# 0                           [Autaugaville, Billingsley]        2.0   AL    01
# 1     [Elberta, Loxley, Magnolia Springs, Perdido Be...        6.0   AL    01
# 2        [Bakerhill, Blue Springs, Clayton, Louisville]        4.0   AL    01
# 3                      [Vance, West Blocton, Woodstock]        3.0   AL    01
# 4     [Allgood, Altoona, Blountsville, Cleveland, Co...       14.0   AL    01
# ...                                                 ...        ...  ...   ...
# 3166                                                NaN        NaN  NaN   NaN
# 3167                                                NaN        NaN  NaN   NaN
# 3168                                                NaN        NaN  NaN   NaN
# 3169                                                NaN        NaN  NaN   NaN
# 3170                                                NaN        NaN  NaN   NaN
#
#      FIPS_code_NEW
# 0            01001
# 1            01003
# 2            01005
# 3            01007
# 4            01009
# ...            ...
# 3166           NaN
# 3167           NaN
# 3168           NaN
# 3169           NaN
# 3170           NaN
#
# [3171 rows x 49 columns]

# %%
all_data_3['Stabr'].unique()
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA',
#        'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA',
#        'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY',
#        'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY', 'PR'], dtype=object)

# %%
# drop PR

county_data = all_data_3[all_data_3['Stabr'] != 'PR']

# %%
county_data['Stabr'].unique()
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA',
#        'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA',
#        'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY',
#        'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY'], dtype=object)

# %%
#check results of merge
county_data.to_csv('county_data_all.csv', index=False)

# %%
with open('county_data.pickle', 'wb') as to_write:
    pickle.dump(county_data, to_write)
